# %% [markdown]
# <a href="https://colab.research.google.com/github/Jmetrics86/fred/blob/main/FRED_API_TEMPLATE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Install fredapi Package

# %%
# !pip install fredapi
# Out:
# Collecting fredapi
#   Downloading fredapi-0.5.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from fredapi) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->fredapi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fredapi) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fredapi) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->fredapi) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->fredapi) (1.16.0)
# Installing collected packages: fredapi
# Successfully installed fredapi-0.5.1

# %% [markdown]
# #Import fredapi and assign API key

# %%
#https://github.com/mortada/fredapi

import pandas as pd
import time
from fredapi import Fred

#replace this api key with an API key for RTdata (free from FRED)
fred = Fred(api_key='enter_your_api_key_here')

# %% [markdown]
# #Search for Series by popular category
# After aggregating, concatenate and drop duplicates

# %%
# prompt: use fredapi to cycle searching through various topics on the list to create a large dataframe of all of the results, after using a for loop to create the master dataframe, remove duplicates.



search_categories = ['Interest Rates', 'Exchange Rates', 'Monetary Data', 'Financial Indicator', 'Banking Industry', 'Business Lending', 'Foreign Exchange Intervention', 'Current Population', 'employment', 'education' , 'income' , 'Job Opening', 'Labor Turnover', 'productivity index', 'cost index', 'minimum wage', 'tax rate', 'retail trade', 'services', 'technology', 'housing', 'expenditures', 'business survey', 'wholesale trade', 'transportation', 'automotive', 'house price indexes', 'cryptocurrency' ]

df_list = []
for category in search_categories:
  search_results = fred.search(category, order_by='popularity', sort_order='desc', limit=1000)
  df = pd.DataFrame(search_results)
  df_list.append(df)
  print(category)
master_df = pd.concat(df_list)
master_df = master_df.drop_duplicates()
master_df['popularity'] = master_df['popularity'].astype(int)
master_df.to_csv('FRED_Search.csv')
# Out:
# Interest Rates
# Exchange Rates
# Monetary Data
# Financial Indicator
# Banking Industry
# Business Lending
# Foreign Exchange Intervention
# Current Population
# employment
# education
# income
# Job Opening
# Labor Turnover
# productivity index
# cost index
# minimum wage
# tax rate
# retail trade
# services
# technology
# housing
# expenditures
# business survey
# wholesale trade
# transportation
# automotive
# house price indexes
# cryptocurrency
# <ipython-input-4-2ca4f3738642>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   master_df['popularity'] = master_df['popularity'].astype(int)

# %% [markdown]
# #Filter Popular Series into Daily, Weekly, Monthly Lists
# Popularity rating over 50 as an additional feature.

# %%
# prompt: using the master_df create a list of series ids filtered down to only series with frequency of daily and popularity above 50.

daily_list = master_df[(master_df['popularity'] >= 50) & (master_df['frequency_short'] == 'D')]
daily_list = daily_list['id'].tolist()
print(daily_list)


# prompt: using the master_df create a list of series ids filtered down to only series with frequency of monthly and popularity above 50.

monthly_list = master_df[(master_df['popularity'] >= 50) & (master_df['frequency_short'] == 'M')]
monthly_list = monthly_list['id'].tolist()
print(monthly_list)

# prompt: using the master_df create a list of series ids filtered down to only series with frequency of weekly and popularity above 50.

weekly_list = master_df[(master_df['popularity'] >= 50) & (master_df['frequency_short'] == 'W')]
weekly_list = weekly_list['id'].tolist()
print(weekly_list)
# Out:
# ['T10Y2Y', 'T10Y3M', 'BAMLH0A0HYM2', 'DGS10', 'T10YIE', 'DFF', 'DFII10', 'T5YIE', 'BAMLH0A0HYM2EY', 'T5YIFR', 'DGS2', 'DFEDTARU', 'BAMLC0A4CBBB', 'DGS1', 'DGS5', 'BAMLC0A0CM', 'BAMLC0A4CBBBEY', 'DGS20', 'DGS30', 'IORB', 'DBAA', 'BAA10Y', 'DTB3', 'DGS3MO', 'T10YFF', 'DPRIME', 'DAAA', 'BAMLH0A3HYC', 'BAMLH0A3HYCEY', 'BAMLH0A1HYBB', 'DGS1MO', 'DFII5', 'BAMLH0A1HYBBEY', 'DGS3', 'IUDSOIA', 'BAMLHE00EHYIEY', 'BAMLH0A2HYBEY', 'TEDRATE', 'BAMLHE00EHYIOAS', 'BAMLC0A1CAAAEY', 'AAA10Y', 'BAMLC0A0CMEY', 'BAMLC0A3CA', 'DGS6MO', 'BAMLH0A2HYB', 'BAMLHYH0A0HYM2TRIV', 'DFEDTARL', 'DGS7', 'DPCREDIT', 'BAMLC0A2CAAEY', 'BAMLC0A3CAEY', 'DFII30', 'BAMLC0A2CAA', 'DTB1YR', 'DTB4WK', 'BAMLC0A1CAAA', 'DFEDTAR', 'IOER', 'DTB6', 'BAMLEMCBPIOAS', 'BAMLC4A0C710YEY', 'BAMLCC0A0CMTRIV', 'DFII20', 'RIFSPPFAAD90NB', 'AMERIBOR', 'BAMLEMHBHYCRPIOAS', 'DTP10J28', 'DLTIIT', 'DTWEXBGS', 'DEXUSEU', 'DEXJPUS', 'DEXCHUS', 'DEXUSUK', 'DEXCAUS', 'DEXKOUS', 'DEXMXUS', 'DTWEXAFEGS', 'DEXINUS', 'DTWEXEMEGS', 'NASDAQ100', 'SP500', 'DJIA', 'OBMMIJUMBO30YF', 'OBMMIVA30YF', 'OBMMIFHA30YF', 'BAMLEMHBHYCRPIOAS', 'ECBESTRVOLWGTTRMDMNRT', 'CBBTCUSD']
# ['FEDFUNDS', 'REAINTRATREARAT10Y', 'AAA', 'TB3MS', 'GS10', 'INTDSRUSM193N', 'BAA', 'TERMCBCCALLNS', 'IRLTLT01USM156N', 'EXPINF10YR', 'USSLIND', 'REAINTRATREARAT1YE', 'EXPINF1YR', 'SNDR', 'PI', 'TERMCBAUTO48NS', 'HQMCB10YR', 'T30YIEM', 'EXPINF30YR', 'T10Y2YM', 'MPRIME', 'EXPINF2YR', 'IRLTLT01JPM156N', 'IRLTLT01DEM156N', 'IRLTLT01GBM156N', 'RIFLPBCIANM60NM', 'GS1', 'IR3TIB01USM156N', 'MMTY', 'EXPINF5YR', 'AMBSL', 'HQMCB10YRP', 'TERMCBPER24NS', 'MVMTD027MNFRBDAL', 'NDR12MCD', 'INTDSRJPM193N', 'GS5', 'INTDSRCNM193N', 'TB3SMFFM', 'EXJPUS', 'RBUSBIS', 'TWEXBGSMTH', 'EXUSEU', 'M2SL', 'M1SL', 'BOGMBASE', 'CURRCIR', 'MABMM301USM189S', 'M2NS', 'CURRSL', 'MBCURRCIR', 'BOGMBBM', 'CSUSHPINSA', 'CIVPART', 'CSUSHPISA', 'UNEMPLOY', 'KCFSI', 'M1109BUSM293NNBR', 'BUSLOANS', 'WPU3911', 'UNRATE', 'LNS14000006', 'LNS11300060', 'CLF16OV', 'CE16OV', 'U6RATE', 'EMRATIO', 'LNS11300002', 'LNS11300001', 'LNS12026620', 'UNRATENSA', 'CNP16OV', 'LNS14000024', 'LNS14000031', 'LNU00074597', 'LNS12500000', 'LNS11324230', 'U2RATE', 'TTLHHM156N', 'LNS12032194', 'LNS14000002', 'CPIAUCSL', 'PAYEMS', 'CES0500000003', 'RECPROUSM156N', 'MANEMP', 'AWHAETP', 'AHETPI', 'USCONS', 'USGOVT', 'TEMPHELPS', 'USPRIV', 'CES4348400001', 'USLAH', 'USPBS', 'USTRADE', 'LNS12300060', 'USINFO', 'CES1021100001', 'USEHS', 'USPHCI', 'CES4300000001', 'AWHMAN', 'USFIRE', 'CES4348100001', 'USMINE', 'USWTRADE', 'CES2000000003', 'USSERV', 'CES3000000003', 'CES9091000001', 'CES0500000011', 'CES7000000003', 'AWHAECON', 'BABANAICSRETSAUS', 'CES4300000003', 'CES6000000003', 'FEDMINNFRWG', 'LREM64TTUSM156S', 'CES4200000003', 'CES6500000003', 'CES5000000003', 'CES5500000003', 'CPIEDUSL', 'PSAVERT', 'PCE', 'PCEPI', 'PCEPILFE', 'DSPIC96', 'PCEC96', 'FIXHAI', 'SPCS20RSA', 'POPTHM', 'PMSAVE', 'DSPI', 'A229RX0', 'SFXRSA', 'LXXRSA', 'SEXRNSA', 'PCEDG', 'SDXRSA', 'RPI', 'NYXRSA', 'CHXRSA', 'DAXRNSA', 'BOXRSA', 'PHXRNSA', 'DNXRSA', 'MIXRNSA', 'DGDSRX1', 'PCES', 'W875RX1', 'PCEDGC96', 'JTSJOL', 'JTSLDL', 'JTSQUR', 'JTSHIL', 'JTSQUL', 'JTSJOR', 'INDPRO', 'WPU0911', 'WPU101707', 'TCU', 'WPU10170502', 'PCU32733273', 'WPU061', 'WPU10', 'WPU101', 'WPU091405', 'APU0000709112', 'WPU1017', 'IPMAN', 'WPU081', 'WPU101211', 'WPU08', 'WPU057303', 'PCU3272132721', 'PCU32221132221102', 'WPU012', 'PCU325212325212P', 'WPU07110224', 'WPU0571', 'PCU325199325199P', 'WPU083', 'WPU0561', 'PCU332618332618', 'WPU0638', 'WPUID51', 'WPUID53', 'WPUID54', 'WPUID52', 'GEPUCURRENT', 'WPU1012', 'WPU102505', 'WPU10170674', 'WPU10230103', 'WPU06130302', 'PCU3364133641', 'WPU09120325', 'CORESTICKM159SFRBATL', 'APU0000708111', 'APU0000703112', 'APU0000702111', 'APU0000FF1101', 'STICKCPIM157SFRBATL', 'APU0000FN1101', 'APU0000718311', 'APU0200FN1102', 'APU0000701111', 'APU0000FS1101', 'APU0000704111', 'CRESTKCPIXSLTRM159SFRBATL', 'APU0300703213', 'APU0000706111', 'TOTALSA', 'RSXFS', 'HTRUCKSSAAR', 'RRSFS', 'RETAILIRSA', 'RSAFS', 'PCUARETTRARETTR', 'WPU5831', 'WPU5811', 'MRTSSM44112USN', 'RETAILIMSA', 'MRTSSM44000USS', 'EXHOSLUSM495S', 'MEDCPIM158SFRBCLE', 'HOSINVUSM495N', 'HOSMEDUSM052N', 'MTSDS133FMS', 'CUSR0000SASLE', 'HOSSUPUSM673N', 'BOPGSTB', 'CUSR0000SAM2', 'WPU43', 'WPSFD49116', 'PPIDSS', 'WPU571', 'WPU5121', 'PPITSS', 'WPU4511', 'PPITWS', 'WPUID63', 'PPIAWS', 'WPU5111', 'RTWEXBGS', 'EXSFHSUSM495S', 'TSIFRGHT', 'HSFMEDUSM052N', 'PCU4831114831115', 'AITINO', 'HOUST', 'ACTLISCOUUS', 'MSACSR', 'PERMIT', 'HSN1F', 'CUSR0000SAF11', 'MSPNHSUS', 'ACTLISCOUFL', 'HOUST1F', 'MEDDAYONMARUS', 'UNDCONTSA', 'CUSR0000SEFV', 'USAUCSFRCONDOSMSAMID', 'HOUST5F', 'ACTLISCOUCA', 'COMPUTSA', 'ACTLISCOU38060', 'MEDLISPRIPERSQUFEEUS', 'ACTLISCOU12420', 'UNDCON5MUSA', 'M0264AUSM500NNBR', 'ACTLISCOU12086', 'ACTLISCOU6073', 'CPIHOSNS', 'PERMIT1', 'ACTLISCOU6037', 'ACTLISCOU19100', 'TTLCONS', 'TLMFGCONS', 'PCETRIM12M159SFRBDAL', 'TLNRESCONS', 'TLRESCONS', 'FRGSHPUSM649NCIS', 'PCUAWHLTRAWHLTR', 'PCU484484', 'PCU483111483111', 'PCUATRNWRATRNWR', 'PCU481481', 'TRUCKD11', 'WPU1411', 'PCU481111481111', 'M12MTVUSM227NFWA', 'TRFVOLUSM227NFWA', 'ADXTNO', 'A36SNO', 'CUSR ...
# ['MORTGAGE30US', 'MORTGAGE15US', 'STLFSI4', 'FF', 'MORTGAGE5US', 'SWPT', 'WGS1YR', 'WGS10YR', 'WM2NS', 'WM1NS', 'M2', 'M1', 'NFCI', 'WEI', 'ANFCI', 'NFCILEVERAGE', 'NFCICREDIT', 'NFCIRISK', 'TOTCI', 'ICSA', 'CCSA', 'IC4WSA', 'ADPWNUSNERSA', 'WORAL', 'CC4WSA', 'GASREGW', 'WRMFNS', 'WRESBAL', 'WRBWFRBL', 'WLRRAL', 'WLODLL', 'CARACBW027SBOG']

# %% [markdown]
# #Daily Data Series Pulls
#
# Pull together daily metrics

# %%
# Create an empty DataFrame to store the merged data
merged_data = pd.DataFrame()
data = pd.DataFrame()

# Loop through each series and merge it into the DataFrame
for series_id in daily_list:
    data = pd.DataFrame(fred.get_series(series_id))
    data['series'] = series_id
    merged_data = pd.concat([merged_data, data], axis=0)
    print(series_id)


# Print the merged DataFrame
merged_data = merged_data.reset_index()
merged_data = merged_data.rename(columns={'index': 'date', 0: 'value'})


print(merged_data)
print(merged_data.info())
merged_data.to_csv('daily_data.csv')
# Out:
# T10Y2Y
# T10Y3M
# BAMLH0A0HYM2
# DGS10
# T10YIE
# DFF
# DFII10
# T5YIE
# BAMLH0A0HYM2EY
# T5YIFR
# DGS2
# DFEDTARU
# BAMLC0A4CBBB
# DGS1
# DGS5
# BAMLC0A0CM
# BAMLC0A4CBBBEY
# DGS20
# DGS30
# IORB
# DBAA
# BAA10Y
# DTB3
# DGS3MO
# T10YFF
# DPRIME
# DAAA
# BAMLH0A3HYC
# BAMLH0A3HYCEY
# BAMLH0A1HYBB
# DGS1MO
# DFII5
# BAMLH0A1HYBBEY
# DGS3
# IUDSOIA
# BAMLHE00EHYIEY
# BAMLH0A2HYBEY
# TEDRATE
# BAMLHE00EHYIOAS
# BAMLC0A1CAAAEY
# AAA10Y
# BAMLC0A0CMEY
# BAMLC0A3CA
# DGS6MO
# BAMLH0A2HYB
# BAMLHYH0A0HYM2TRIV
# DFEDTARL
# DGS7
# DPCREDIT
# BAMLC0A2CAAEY
# BAMLC0A3CAEY
# DFII30
# BAMLC0A2CAA
# DTB1YR
# DTB4WK
# BAMLC0A1CAAA
# DFEDTAR
# IOER
# DTB6
# BAMLEMCBPIOAS
# BAMLC4A0C710YEY
# BAMLCC0A0CMTRIV
# DFII20
# RIFSPPFAAD90NB
# AMERIBOR
# BAMLEMHBHYCRPIOAS
# DTP10J28
# DLTIIT
# DTWEXBGS
# DEXUSEU
# DEXJPUS
# DEXCHUS
# DEXUSUK
# DEXCAUS
# DEXKOUS
# DEXMXUS
# DTWEXAFEGS
# DEXINUS
# DTWEXEMEGS
# NASDAQ100
# SP500
# DJIA
# OBMMIJUMBO30YF
# OBMMIVA30YF
# OBMMIFHA30YF
# BAMLEMHBHYCRPIOAS
# ECBESTRVOLWGTTRMDMNRT
# CBBTCUSD
#              date     value    series
# 0      1976-06-01      0.68    T10Y2Y
# 1      1976-06-02      0.71    T10Y2Y
# 2      1976-06-03      0.70    T10Y2Y
# 3      1976-06-04      0.77    T10Y2Y
# 4      1976-06-07      0.79    T10Y2Y
# ...           ...       ...       ...
# 760928 2024-04-10  70554.77  CBBTCUSD
# 760929 2024-04-11  70001.36  CBBTCUSD
# 760930 2024-04-12  67107.27  CBBTCUSD
# 760931 2024-04-13  64034.00  CBBTCUSD
# 760932 2024-04-14  65643.19  CBBTCUSD
#
# [760933 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760933 entries, 0 to 760932
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    760933 non-null  datetime64[ns]
#  1   value   729451 non-null  float64
#  2   series  760933 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 17.4+ MB
# None

# %% [markdown]
# #Monthly Data Series Pulls

# %%
# Create an empty DataFrame to store the merged data
monthly_merged_data = pd.DataFrame()
data = pd.DataFrame()

# Loop through each series and merge it into the DataFrame
for series_id in monthly_list:
    data = pd.DataFrame(fred.get_series(series_id))
    data['series'] = series_id
    monthly_merged_data = pd.concat([monthly_merged_data, data], axis=0)
    print(series_id)
    time.sleep(0.5)


# Print the merged DataFrame
monthly_merged_data = monthly_merged_data.reset_index()
monthly_merged_data = monthly_merged_data.rename(columns={'index': 'date', 0: 'value'})


print(monthly_merged_data)
print(monthly_merged_data.info())
monthly_merged_data.to_csv('monthly_data.csv')
# Out:
# FEDFUNDS
# REAINTRATREARAT10Y
# AAA
# TB3MS
# GS10
# INTDSRUSM193N
# BAA
# TERMCBCCALLNS
# IRLTLT01USM156N
# EXPINF10YR
# USSLIND
# REAINTRATREARAT1YE
# EXPINF1YR
# SNDR
# PI
# TERMCBAUTO48NS
# HQMCB10YR
# T30YIEM
# EXPINF30YR
# T10Y2YM
# MPRIME
# EXPINF2YR
# IRLTLT01JPM156N
# IRLTLT01DEM156N
# IRLTLT01GBM156N
# RIFLPBCIANM60NM
# GS1
# IR3TIB01USM156N
# MMTY
# EXPINF5YR
# AMBSL
# HQMCB10YRP
# TERMCBPER24NS
# MVMTD027MNFRBDAL
# NDR12MCD
# INTDSRJPM193N
# GS5
# INTDSRCNM193N
# TB3SMFFM
# EXJPUS
# RBUSBIS
# TWEXBGSMTH
# EXUSEU
# M2SL
# M1SL
# BOGMBASE
# CURRCIR
# MABMM301USM189S
# M2NS
# CURRSL
# MBCURRCIR
# BOGMBBM
# CSUSHPINSA
# CIVPART
# CSUSHPISA
# UNEMPLOY
# KCFSI
# M1109BUSM293NNBR
# BUSLOANS
# WPU3911
# UNRATE
# LNS14000006
# LNS11300060
# CLF16OV
# CE16OV
# U6RATE
# EMRATIO
# LNS11300002
# LNS11300001
# LNS12026620
# UNRATENSA
# CNP16OV
# LNS14000024
# LNS14000031
# LNU00074597
# LNS12500000
# LNS11324230
# U2RATE
# TTLHHM156N
# LNS12032194
# LNS14000002
# CPIAUCSL
# PAYEMS
# CES0500000003
# RECPROUSM156N
# MANEMP
# AWHAETP
# AHETPI
# USCONS
# USGOVT
# TEMPHELPS
# USPRIV
# CES4348400001
# USLAH
# USPBS
# USTRADE
# LNS12300060
# USINFO
# CES1021100001
# USEHS
# USPHCI
# CES4300000001
# AWHMAN
# USFIRE
# CES4348100001
# USMINE
# USWTRADE
# CES2000000003
# USSERV
# CES3000000003
# CES9091000001
# CES0500000011
# CES7000000003
# AWHAECON
# BABANAICSRETSAUS
# CES4300000003
# CES6000000003
# FEDMINNFRWG
# LREM64TTUSM156S
# CES4200000003
# CES6500000003
# CES5000000003
# CES5500000003
# CPIEDUSL
# PSAVERT
# PCE
# PCEPI
# PCEPILFE
# DSPIC96
# PCEC96
# FIXHAI
# SPCS20RSA
# POPTHM
# PMSAVE
# DSPI
# A229RX0
# SFXRSA
# LXXRSA
# SEXRNSA
# PCEDG
# SDXRSA
# RPI
# NYXRSA
# CHXRSA
# DAXRNSA
# BOXRSA
# PHXRNSA
# DNXRSA
# MIXRNSA
# DGDSRX1
# PCES
# W875RX1
# PCEDGC96
# JTSJOL
# JTSLDL
# JTSQUR
# JTSHIL
# JTSQUL
# JTSJOR
# INDPRO
# WPU0911
# WPU101707
# TCU
# WPU10170502
# PCU32733273
# WPU061
# WPU10
# WPU101
# WPU091405
# APU0000709112
# WPU1017
# IPMAN
# WPU081
# WPU101211
# WPU08
# WPU057303
# PCU3272132721
# PCU32221132221102
# WPU012
# PCU325212325212P
# WPU07110224
# WPU0571
# PCU325199325199P
# WPU083
# WPU0561
# PCU332618332618
# WPU0638
# WPUID51
# WPUID53
# WPUID54
# WPUID52
# GEPUCURRENT
# WPU1012
# WPU102505
# WPU10170674
# WPU10230103
# WPU06130302
# PCU3364133641
# WPU09120325
# CORESTICKM159SFRBATL
# APU0000708111
# APU0000703112
# APU0000702111
# APU0000FF1101
# STICKCPIM157SFRBATL
# APU0000FN1101
# APU0000718311
# APU0200FN1102
# APU0000701111
# APU0000FS1101
# APU0000704111
# CRESTKCPIXSLTRM159SFRBATL
# APU0300703213
# APU0000706111
# TOTALSA
# RSXFS
# HTRUCKSSAAR
# RRSFS
# RETAILIRSA
# RSAFS
# PCUARETTRARETTR
# WPU5831
# WPU5811
# MRTSSM44112USN
# RETAILIMSA
# MRTSSM44000USS
# EXHOSLUSM495S
# MEDCPIM158SFRBCLE
# HOSINVUSM495N
# HOSMEDUSM052N
# MTSDS133FMS
# CUSR0000SASLE
# HOSSUPUSM673N
# BOPGSTB
# CUSR0000SAM2
# WPU43
# WPSFD49116
# PPIDSS
# WPU571
# WPU5121
# PPITSS
# WPU4511
# PPITWS
# WPUID63
# PPIAWS
# WPU5111
# RTWEXBGS
# EXSFHSUSM495S
# TSIFRGHT
# HSFMEDUSM052N
# PCU4831114831115
# AITINO
# HOUST
# ACTLISCOUUS
# MSACSR
# PERMIT
# HSN1F
# CUSR0000SAF11
# MSPNHSUS
# ACTLISCOUFL
# HOUST1F
# MEDDAYONMARUS
# UNDCONTSA
# CUSR0000SEFV
# USAUCSFRCONDOSMSAMID
# HOUST5F
# ACTLISCOUCA
# COMPUTSA
# ACTLISCOU38060
# MEDLISPRIPERSQUFEEUS
# ACTLISCOU12420
# UNDCON5MUSA
# M0264AUSM500NNBR
# ACTLISCOU12086
# ACTLISCOU6073
# CPIHOSNS
# PERMIT1
# ACTLISCOU6037
# ACTLISCOU19100
# TTLCONS
# TLMFGCONS
# PCETRIM12M159SFRBDAL
# TLNRESCONS
# TLRESCONS
# FRGSHPUSM649NCIS
# PCUAWHLTRAWHLTR
# PCU484484
# PCU483111483111
# PCUATRNWRATRNWR
# PCU481481
# TRUCKD11
# WPU1411
# PCU481111481111
# M12MTVUSM227NFWA
# TRFVOLUSM227NFWA
# ADXTNO
# A36SNO
# CUSR0000SETA02
# CUUR0000SETA01
# ALTSALES
# AUINSA
# CUSR0000SETA01
# AMVPNO
# AISRSA
# DAUPSA
# PCU336110336110
# PCU441110441110
# CUSR0000SETD
#              date    value        series
# 0      1954-07-01    0.800      FEDFUNDS
# 1      1954-08-01    1.220      FEDFUNDS
# 2      1954-09-01    1.070      FEDFUNDS
# 3      1954-10-01    0.850      FEDFUNDS
# 4      1954-11-01    0.830      FEDFUNDS
# ...           ...      ...           ...
# 169582 2023-11-01  393.924  CUSR0000SETD
# 169583 2023-12-01  392.897  CUSR0000SETD
# 169584 2024-01-01  396.004  CUSR0000SETD
# 169585 2024-02-01  397.541  CUSR0000SETD
# 169586 2024-03-01  404.475  CUSR0000SETD
#
# [169587 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169587 entries, 0 to 169586
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    169587 non-null  datetime64[ns]
#  1   value   165872 non-null  float64
#  2   series  169587 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 3.9+ MB
# None

# %% [markdown]
# # Weekly Data Series Pulls

# %%
# Create an empty DataFrame to store the merged data
monthly_merged_data = pd.DataFrame()
data = pd.DataFrame()

# Loop through each series and merge it into the DataFrame
for series_id in weekly_list:
    data = pd.DataFrame(fred.get_series(series_id))
    data['series'] = series_id
    monthly_merged_data = pd.concat([monthly_merged_data, data], axis=0)
    print(series_id)
    time.sleep(0.5)


# Print the merged DataFrame
monthly_merged_data = monthly_merged_data.reset_index()
monthly_merged_data = monthly_merged_data.rename(columns={'index': 'date', 0: 'value'})


print(monthly_merged_data)
print(monthly_merged_data.info())
monthly_merged_data.to_csv('weekly_data.csv')
# Out:
# MORTGAGE30US
# MORTGAGE15US
# STLFSI4
# FF
# MORTGAGE5US
# SWPT
# WGS1YR
# WGS10YR
# WM2NS
# WM1NS
# M2
# M1
# NFCI
# WEI
# ANFCI
# NFCILEVERAGE
# NFCICREDIT
# NFCIRISK
# TOTCI
# ICSA
# CCSA
# IC4WSA
# ADPWNUSNERSA
# WORAL
# CC4WSA
# GASREGW
# WRMFNS
# WRESBAL
# WRBWFRBL
# WLRRAL
# WLODLL
# CARACBW027SBOG
#             date     value          series
# 0     1971-04-02    7.3300    MORTGAGE30US
# 1     1971-04-09    7.3100    MORTGAGE30US
# 2     1971-04-16    7.3100    MORTGAGE30US
# 3     1971-04-23    7.3100    MORTGAGE30US
# 4     1971-04-30    7.2900    MORTGAGE30US
# ...          ...       ...             ...
# 68759 2024-03-06  496.4243  CARACBW027SBOG
# 68760 2024-03-13  495.4374  CARACBW027SBOG
# 68761 2024-03-20  494.9728  CARACBW027SBOG
# 68762 2024-03-27  493.6432  CARACBW027SBOG
# 68763 2024-04-03  492.7477  CARACBW027SBOG
#
# [68764 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68764 entries, 0 to 68763
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    68764 non-null  datetime64[ns]
#  1   value   68758 non-null  float64
#  2   series  68764 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 1.6+ MB
# None
